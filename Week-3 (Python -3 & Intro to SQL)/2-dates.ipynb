# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2026-09-22 09:01:10.630719

# %%
import datetime

x = datetime.datetime.now()

print(x.year)
print(x.strftime("%A"))
# Out:
# 2026
# Tuesday

# %%
import datetime

x = datetime.datetime(2020, 5, 17)

print(x)
# Out:
# 2020-05-17 00:00:00

# %%
import datetime

x = datetime.datetime.now()
# Out:
# June

# %%
import datetime

x = datetime.datetime.now()

print(x.strftime("%j"))
# Out:
# 265
