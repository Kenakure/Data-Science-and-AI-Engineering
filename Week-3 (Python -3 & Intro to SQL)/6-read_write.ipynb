# %%
f = open("demofile.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open("demofile.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demofile.txt'

# %%
f = open("demofile.txt", "rt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f = open("demofile.txt", "rt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demofile.txt'

# %%
with open("notes.txt", "w") as f:
    f.write("Week 1: Python basics\n")
    f.write("Week 2: OOP and inheritance\n")
    f.write("Week 3: Modules and PIP\n")

# %%
with open("notes.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Week 1: Python basics
# Week 2: OOP and inheritance
# Week 3: Modules and PIP

# %%
Hello! Welcome to demofile.txt  
This file is for testing purposes.  
Good Luck!

# %%
f = open("demofile.txt", "r")  
print(f.read())

# %%
f = open("students.txt", "r")  
print(f.read())

# %%
f= open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt")
print(f.read())
# Out:
# Bola Ahmed Tinubu
# Peter Gregory Obi
# Atiku Abubakar
# Kashim Shetima
# Rabiu Kwankwaso
# Rotimi Amaechi

# %%
with open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt") as f:
    print(f.read())
# Out:
# Bola Ahmed Tinubu
# Peter Gregory Obi
# Atiku Abubakar
# Kashim Shetima
# Rabiu Kwankwaso
# Rotimi Amaechi

# %%
f= open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt")
print(f.read())
f.close()
# Out:
# Bola Ahmed Tinubu
# Peter Gregory Obi
# Atiku Abubakar
# Kashim Shetima
# Rabiu Kwankwaso
# Rotimi Amaechi

# %%
with open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt") as f:  
    print(f.read(5))
# Out:
# Bola

# %%
with open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt") as f:  
    print(f.readline())
# Out:
# Bola Ahmed Tinubu

# %%
with open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt") as f:  
    print(f.readline())  
    print(f.readline())
# Out:
# Bola Ahmed Tinubu
#
# Peter Gregory Obi

# %%
with open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt") as f:  
    for x in f:  
        print(x)
# Out:
# Bola Ahmed Tinubu
#
# Peter Gregory Obi
#
# Atiku Abubakar
#
# Kashim Shetima
#
# Rabiu Kwankwaso
#
# Rotimi Amaechi

# %%
with open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt", "a") as f:  
    f.write("Nyesom Wike the mighty!")  
# Open and read the file after appending:  
with open("/Users/kennethakure/Desktop/dataraflow-cohort-2-main/dataraflow-cohort-2/Week-1 (Overview, Intro, Setup)/students.txt") as f:  
    print(f.read())
# Out:
# Bola Ahmed Tinubu
# Peter Gregory Obi
# Atiku Abubakar
# Kashim Shetima
# Rabiu Kwankwaso
# Rotimi Amaechi
# Nyesom Wike the mighty!

# %%
f = open("myfile.txt", "x")

# %%
import os  
os.remove("myfile.txt")

# %%
import os  
if os.path.exists("myfile.txt"):  
    os.remove("myfile.txt")  
else:  
    print("The file does not exist")
# Out:
# The file does not exist

# %%
import os  
if os.path.exists("myfolder"):  
    os.rmdir("myfolder")

# %%
import os  
if os.path.exists("myfolder"):  
    os.rmdir("myfolder")  
else:  
    print("The folder does not exist")
# Out:
# The folder does not exist
